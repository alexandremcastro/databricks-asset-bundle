# %% [markdown]
# # Imports

# %%
from pyspark.sql.functions import DataFrame

# %%
from src.helpers.parameters import get_path

# %% [markdown]
# # Parameters

# %%
#############################
## Getting dynamic parameters
#############################

## Defining the project
PROJECT: str = dbutils.widgets.get("PROJECT")

## Defining the path
PATH: str = get_path(PROJECT)

# %%
df_nyc_analysis: DataFrame = spark.table(PATH)

# %%
df_nyc_analysis.display()
